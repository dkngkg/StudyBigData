# %% [markdown]
# ## 지리정보 분석
#
# ### 커피매장 주소 표시
#
# #### 패키지 라이브러리 import

# %%
# folium 라이브러리 설치
# !pip install folium

# %%
# 라이브러리 추가할 때 마다 이 셀에 
import pandas as pd
import folium

# %%
cb_data = pd.read_csv('./data/CoffeeBean.csv', encoding='utf-8')
cb_data.head()
# Out:
#    Unnamed: 0    store                     address         phone
# 0           0  학동역 DT점        서울시 강남구 학동로 211 1층    02-3444-9973
# 1           1      수서점  서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2           2     차병원점   서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3           3    강남대로점       서울시 서초구 강남대로 369 1층     02-588-5778
# 4           4    메가박스점  서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320

# %%
# 현재 주소 체계 확인
addr = []

for address in cb_data.address:
    addr.append(str(address).split())
addr
# Out:
# [['서울시', '강남구', '학동로', '211', '1층'],
#  ['서울시', '강남구', '광평로', '280', '수서동', '724호'],
#  ['서울시', '강남구', '논현로', '566', '강남차병원1층'],
#  ['서울시', '서초구', '강남대로', '369', '1층'],
#  ['서울', '강남구', '삼성동', '159', '코엑스몰', '지하2층'],
#  ['서울시', '강남구', '압구정로', '46길', '3'],
#  ['서울시', '서초구', '서초', '1306-3호'],
#  ['서울시', '강남구', '압구정로', '461', '네이처포엠빌딩B108,109호'],
#  ['서울시', '강남구', '도산대로', '126'],
#  ['서울시', '강남구', '논현로', '842', '압구정빌딩1층'],
#  ['서울시', '강남구', '논현로', '512', '지상1,2층'],
#  ['서울시', '서초구', '강남대로', '213', '24호', '지하1층'],
#  ['서울시', '강남구', '삼성로', '716', 'LEE76빌딩2층'],
#  ['서울', '서초구', '반포동', '736-17', 'P빌딩', '2층'],
#  ['서울시', '강남구', '언주로', '30길', '10,112', '현대비젼21', '112호'],
#  ['서울시', '강남구', '선릉로', '749', '1,2층'],
#  ['서울시', '강남구', '테헤란로', '87길', '17', '1층'],
#  ['서울시', '서초구', '서초중앙로', '118', '1층'],
#  ['서울시', '강남구', '선릉로', '64길', '23', '1층'],
#  ['서울시', '강남구', '도산대로49길', '13', '1층', '17,18호'],
#  ['서울시', '강남구', '선릉로', '157길', '12', '석전빌딩', '1~4층'],
# ...

# %%
# addr2를 DataFrame 으로 변경
addr2 = pd.DataFrame(addr2, columns = ['address2'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\localRepository\StudyBigData\day06\커피빈_매장주소_분석.ipynb 셀 7 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#W6sZmlsZQ%3D%3D?line=0'>1</a> # addr2를 DataFrame 으로 변경
# ----> <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#W6sZmlsZQ%3D%3D?line=1'>2</a> addr2 = pd.DataFrame(addr2, columns = ['address2'])
#
# NameError: name 'addr2' is not defined

# %%
cb_data2 = pd.concat([cb_data, addr2], axis ='columns')
cb_data2.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\localRepository\StudyBigData\day06\커피빈_매장주소_분석.ipynb 셀 8 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#X10sZmlsZQ%3D%3D?line=0'>1</a> cb_data2 = pd.concat([cb_data, addr2], axis ='columns')
#       <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#X10sZmlsZQ%3D%3D?line=1'>2</a> cb_data2.head()
#
# NameError: name 'addr2' is not defined

# %%
#중간 저장
cb_data2.to_csv('./data/CoffeeBean_2.csv', encoding = 'utf-8', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\localRepository\StudyBigData\day06\커피빈_매장주소_분석.ipynb 셀 9 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> #중간 저장
# ----> <a href='vscode-notebook-cell:/c%3A/localRepository/StudyBigData/day06/%EC%BB%A4%ED%94%BC%EB%B9%88_%EB%A7%A4%EC%9E%A5%EC%A3%BC%EC%86%8C_%EB%B6%84%EC%84%9D.ipynb#X11sZmlsZQ%3D%3D?line=1'>2</a> cb_data2.to_csv('./data/CoffeeBean_2.csv', encoding = 'utf-8', index=False)
#
# NameError: name 'cb_data2' is not defined

# %% [markdown]
# ### folium 사용법

# %%
map = folium.Map(location= [35.172801, 129.130628], zoom_start=12, tiles ='stamen terrain')
map                                                     

# tiles = 'stamen terraine  : 지형을 높낮이로 나타내줌
# iles = 'Stamen Toner' : 프린트 토너 처럼 나옴
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
# html 저장
map.save('./data/map.html')

# %% [markdown]
# ### MARKER 표시

# %%
map = folium.Map(location= [35.172801, 129.130628], zoom_start=15)

folium.Marker(location= [35.172801, 129.130628], popup='부산산업진흥원', 
icon=folium.Icon(color='blue', icon='home')).add_to(map)
map


## icon = ok, 등등으로 바꿀 수 있다.
# bootstrap icons 에서 변경 할 수 있다. folium의 Marker list 사이트임
# https://getbootstrap.com/docs/3.3/components/
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %% [markdown]
# #### CoffeeBean 매장주소 위도/경도 정리
#  - 차후 다른 방법 검색 요

# %%
cb_geoData = pd.read_csv('./data/CoffeeBean_geo.csv', encoding = 'utf-8')
cb_geoData.head()
# Out:
#    No    store                     address         phone  \
# 0   1  학동역 DT점        서울시 강남구 학동로 211 1층    02-3444-9973
# 1   2      수서점  서울시 강남구 광평로 280 수서동 724호    02-3412-2326
# 2   3     차병원점   서울시 강남구 논현로 566 강남차병원1층     02-538-7615
# 3   4    강남대로점       서울시 서초구 강남대로 369 1층     02-588-5778
# 4   5    메가박스점  서울 강남구 삼성동 159 코엑스몰 지하2층    02-6002-3320
#
#                       address2          경도         위도   상태
# 0         서울특별시 강남구 학동로 211 1층  127.032053  37.514678  정좌표
# 1   서울특별시 강남구 광평로 280 수서동 724호  127.103108  37.487319  정좌표
# 2    서울특별시 강남구 논현로 566 강남차병원1층  127.034824  37.506440  정좌표
# 3        서울특별시 서초구 강남대로 369 1층  127.028217  37.495661  정좌표
# 4  서울특별시 강남구 삼성동 159 코엑스몰 지하2층  127.058795  37.512512  정좌표

# %%
map_cb = folium.Map(location= [35.172801, 129.130628], zoom_start = 15)
map_cb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
for i, store in cb_geoData.iterrows():
    print(i)
    print(store)
    if i == 2: break


# 알기) iterrows 를 사용하여 반복문을 사용하면, 2가지 값이 출력된다.  여기선 i 와 store 값이다.
# Out:
# 0
# No                             1
# store                    학동역 DT점
# address     서울시 강남구 학동로 211 1층
# phone               02-3444-9973
# address2    서울특별시 강남구 학동로 211 1층
# 경도                    127.032053
# 위도                     37.514678
# 상태                           정좌표
# Name: 0, dtype: object
# 1
# No                                   2
# store                              수서점
# address     서울시 강남구 광평로 280 수서동 724호
# phone                     02-3412-2326
# address2    서울특별시 강남구 광평로 280 수서동 724호
# 경도                          127.103108
# 위도                           37.487319
# 상태                                 정좌표
# Name: 1, dtype: object
# 2
# No                                  3
# store                            차병원점
# address     서울시 강남구 논현로 566 강남차병원1층
# phone                     02-538-7615
# address2    서울특별시 강남구 논현로 566 강남차병원1층
# 경도                         127.034824
# 위도                           37.50644
# 상태                                정좌표
# ...

# %%
for store in cb_geoData.iterrows():
    print(store)
# Out:
# (0, No                             1
# store                    학동역 DT점
# address     서울시 강남구 학동로 211 1층
# phone               02-3444-9973
# address2    서울특별시 강남구 학동로 211 1층
# 경도                    127.032053
# 위도                     37.514678
# 상태                           정좌표
# Name: 0, dtype: object)
# (1, No                                   2
# store                              수서점
# address     서울시 강남구 광평로 280 수서동 724호
# phone                     02-3412-2326
# address2    서울특별시 강남구 광평로 280 수서동 724호
# 경도                          127.103108
# 위도                           37.487319
# 상태                                 정좌표
# Name: 1, dtype: object)
# (2, No                                  3
# store                            차병원점
# address     서울시 강남구 논현로 566 강남차병원1층
# phone                     02-538-7615
# address2    서울특별시 강남구 논현로 566 강남차병원1층
# 경도                         127.034824
# 위도                           37.50644
# 상태                                정좌표
# ...

# %%
for i, store in cb_geoData.iterrows():
    folium.Marker(location=[store['위도'], store['경도']], popup=store['store'], 
    icon=folium.Icon(color='purple', icon='home')).add_to(map_cb)
    

# 알기) iterrows 를 사용하여 반복문을 사용하면, 2가지 값이 출력된다.  여기선 i 와 store 값이다.

# %%
map_cb
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
# ...

# %%
map_cb.save('./data/CoffeeBean__shop.html')

# %%
import webbrowser
# 상대경로는 쓸수 없음
webbrowser.open('C:\localRepository\StudyBigData\day06\data\CoffeeBean__shop.html')
# Out:
# True
